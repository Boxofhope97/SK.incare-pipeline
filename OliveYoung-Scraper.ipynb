# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import csv
from deep_translator import GoogleTranslator
import re

url = 'https://www.oliveyoung.co.kr/store/main/getBestList.do?dispCatNo=900000100100001&fltDispCatNo=10000010001&pageIdx=1&rowsPerPage=8&t_page=%EB%9E%AD%ED%82%B9&t_click=%ED%8C%90%EB%A7%A4%EB%9E%AD%ED%82%B9_skin+care'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
websitecode = soup.find_all('div', class_='prd_info ')

productlist = []

for item in websitecode:
    # Extract brand, name + Translate brand, name from Korean to English
    brand_kr = item.find('span', class_='tx_brand').text.strip()
    name_kr = item.find('p', class_='tx_name').text.strip()
    brand = GoogleTranslator(source='auto', target='en').translate(brand_kr)
    name = GoogleTranslator(source='auto', target='en').translate(name_kr)
    product_link = item.find('a', href=True)
    print(product_link)

    # product_info = {"brand": brand, "name": name}
                
    # append dictionary to product list
    # roductlist.append(product_info)
    # print(productlist)

# %%
print(websitecode)
# Out:
# [<div class="prd_name"><a class="goodsList" data-attr="null" data-ref-dispcatno="90000010009" data-ref-goodsno="A000000188968" data-ref-itemno="001" data-trk="null" href="javascript:;" name="Best_Sellingbest"><span class="tx_brand">디마르3</span><p class="tx_name">[리뷰이벤트/모공교정앰플] 디마르3 시그니처 에스투드 프로텍터 대용량 앰플 170ml</p></a></div>, <div class="prd_name"><a class="goodsList" data-attr="null" data-ref-dispcatno="90000010009" data-ref-goodsno="A000000188240" data-ref-itemno="001" data-trk="null" href="javascript:;" name="Best_Sellingbest"><span class="tx_brand">성분에디터</span><p class="tx_name">[서강준 Pick] 성분에디터 그린토마토 포어 리프팅 앰플 플러스 30ml 더블 기획</p></a></div>, <div class="prd_name"><a class="goodsList" data-attr="null" data-ref-dispcatno="90000010009" data-ref-goodsno="A000000184128" data-ref-itemno="001" data-trk="null" href="javascript:;" name="Best_Sellingbest"><span class="tx_brand">에스트라</span><p class="tx_name">에스트라 아토베리어365 크림 80ml 기획 (+하이드로에센스 25ml+무기자차선크림10ml 증정)</p></a></div>, <div class="prd_
# ...

# %%
# create a dictionary for each product
for item in websitecode:
# Out:
# [{'brand': 'estra', 'name': 'Aestura Terracne 365 Active Serum 30ml special (+ 30g cleansing foam + 25ml toner) (2307)'}, {'brand': 'estra', 'name': 'Aestura Terracne 365 Active Serum 30ml special (+ 30g cleansing foam + 25ml toner) (2307)'}]
# [{'brand': 'estra', 'name': 'Aestura Terracne 365 Active Serum 30ml special (+ 30g cleansing foam + 25ml toner) (2307)'}, {'brand': 'estra', 'name': 'Aestura Terracne 365 Active Serum 30ml special (+ 30g cleansing foam + 25ml toner) (2307)'}, {'brand': 'estra', 'name': 'Aestura Terracne 365 Active Serum 30ml special (+ 30g cleansing foam + 25ml toner) (2307)'}]
# ...

# %%
# export productlist to Pandas dataframe
df = pd.DataFrame(productlist)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# create csv and write dataframe to it
csv_file_path = 'OliveYoungBestsellers.csv'
df.to_csv(csv_file_path, index=False, encoding='utf-8')

print(f"Data exported to {csv_file_path}")
# Out:
# Data exported to OliveYoungBestsellers.csv

# %%
price_pattern = r(<span class="tx_num"><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">)([^<]+)

# Extract current price, original price + calculate discount percent
    current_price_tag = item.find('span', class_='tx_cur')
    if current_price_tag:
        current_price_match = re.search(price_pattern, current_price_tag)
        current_price = current_price_match.group(2)
        # original_price_tag = item.find('span', class_='tx_org')
        # original_price = old_price_tag.find('span', class_='tx_num').text.strip()
        # ((original_price - current_price) / original_price) * 100

# %%
* link with product page = pull price + ratings info
* calculate discount percentage (in script or dbt model?)
* put into list / table
* put into table

* export to CSV
* export to db directly

* translate to english (transformation) - research this

* try + except for error handling (in loop, JWR video 18:45)
# Out:
#   Cell In[47], line 1
#     * link with product page = pull price + ratings info
#            ^
# SyntaxError: invalid syntax
